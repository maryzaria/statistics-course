# %%
import pandas as pd

star = pd.read_excel('C:/Users/user/Jupyter/StarWars.xlsx')
star
# Out:
#       respondentID seen  fan gender age_group             income  \
# 0       3292879998   да   да      М     18-29                NaN
# 1       3292879538  нет  NaN      М     18-29         0 - 24.999
# 2       3292765271   да  нет      М     18-29         0 - 24.999
# 3       3292763116   да   да      М     18-29  100.000 - 149.999
# 4       3292731220   да   да      М     18-29  100.000 - 149.999
# ...            ...  ...  ...    ...       ...                ...
# 1181    3288388730   да   да      Ж     18-29         0 - 24.999
# 1182    3288378779   да   да      Ж     30-44    50.000 - 99.999
# 1183    3288375286  нет  NaN      Ж     30-44    50.000 - 99.999
# 1184    3288373068   да   да      Ж     45-60  100.000 - 149.999
# 1185    3288372923   да  нет      Ж      > 60    50.000 - 99.999
#
#                                loc                      yoda  \
# 0               Южно-Атлантический            очень нравится
# ...

# %%
star.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   respondentID          1186 non-null   int64
#  1   seen                  1186 non-null   object
#  2   fan                   836 non-null    object
#  3   gender                1046 non-null   object
#  4   age_group             1046 non-null   object
#  5   income                858 non-null    object
#  6   loc                   1043 non-null   object
#  7   yoda                  826 non-null    object
#  8   princess_leia_organa  831 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 83.5+ KB

# %%
bikes[(bikes['Holiday'] == 'Holiday') & 
      (bikes['Temperature'] > 15)].shape

# %%
star[(star['gender']=='М') & (star['age_group'] == '18-29') & 
     (star['fan'] == 'нет')].sort_values(by='loc')
# Out:
#       respondentID seen  fan gender age_group             income  \
# 33      3292318652   да  нет      М     18-29    50.000 - 99.999
# 604     3290124259   да  нет      М     18-29           150.000+
# 448     3290552963   да  нет      М     18-29    50.000 - 99.999
# 941     3289198607   да  нет      М     18-29    25.000 - 49.999
# 2       3292765271   да  нет      М     18-29         0 - 24.999
# 521     3290342169   да  нет      М     18-29    50.000 - 99.999
# 225     3290947011   да  нет      М     18-29  100.000 - 149.999
# 203     3290994001   да  нет      М     18-29         0 - 24.999
# 91      3291618031   да  нет      М     18-29                NaN
# 32      3292330840   да  нет      М     18-29                NaN
# 1039    3288617091   да  нет      М     18-29  100.000 - 149.999
# 59      3292143503   да  нет      М     18-29    50.000 - 99.999
# 48      3292187343   да  нет      М     18-29    50.000 - 99.999
# ...

# %%
star[(star['gender']=='М') & (star['age_group'] == '18-29') & 
     (star['fan'] == 'нет')]['loc'].value_counts()
# Out:
# Тихоокеанский                  8
# Средне-Атлантический           5
# Новая Англия                   3
# Северо-Западный центральный    2
# Южно-Атлантический             1
# Юго-Восточный центральный      1
# Горный                         1
# Name: loc, dtype: int64

# %%
star[(star['gender']=='Ж') & (star['age_group'] == '> 60') & 
     (star['fan'] == 'да') & (star['income'] == '150.000+')] #['loc']value_counts()
# Out:
#      respondentID seen fan gender age_group    income  \
# 162    3291141478   да  да      Ж      > 60  150.000+
# 522    3290342102   да  да      Ж      > 60  150.000+
# 671    3289963393   да  да      Ж      > 60  150.000+
#
#                              loc            yoda princess_leia_organa
# 162                Тихоокеанский  очень нравится       очень нравится
# 522  Северо-Западный центральный  очень нравится       очень нравится
# 671                       Горный  очень нравится       очень нравится

# %%
star.sort_values(by='income')
# Out:
#       respondentID seen  fan gender age_group      income  \
# 1       3292879538  нет  NaN      М     18-29  0 - 24.999
# 203     3290994001   да  нет      М     18-29  0 - 24.999
# 206     3290987996   да   да      М     30-44  0 - 24.999
# 851     3289539921   да   да      Ж     30-44  0 - 24.999
# 850     3289540349   да   да      М     18-29  0 - 24.999
# ...            ...  ...  ...    ...       ...         ...
# 1170    3288402717  нет  NaN      Ж     45-60         NaN
# 1172    3288402592   да   да      Ж      > 60         NaN
# 1173    3288402511   да   да      Ж     30-44         NaN
# 1174    3288401681   да  нет      Ж      > 60         NaN
# 1178    3288395255  нет  NaN      Ж     18-29         NaN
#
#                                loc            yoda princess_leia_organa
# 1         Юго-Западный центральный             NaN                  NaN
# 203           Средне-Атлантический        нравится       очень нравится
# ...

# %%
star['loc'].value_counts()
# Out:
# Северо-Восточный центральный    181
# Тихоокеанский                   175
# Южно-Атлантический              170
# Средне-Атлантический            122
# Юго-Западный центральный        110
# Северо-Западный центральный      93
# Горный                           79
# Новая Англия                     75
# Юго-Восточный центральный        38
# Name: loc, dtype: int64

# %%
star[star['loc'] == 'Северо-Восточный центральный'].shape
# Out:
# (181, 9)

# %%
star[star['loc'] == 'Тихоокеанский'].shape
# Out:
# (175, 9)

# %%
star[star['loc'] == 'Южно-Атлантический'].shape
# Out:
# (170, 9)

# %%
star[star['loc'] == 'Средне-Атлантический'].shape
# Out:
# (122, 9)

# %%
star[star['loc'] == 'Горный'].shape
# Out:
# (79, 9)

# %%
star[(star['gender']=='М') & 
     (star['loc'] == 'Горный')]
# Out:
#       respondentID seen  fan gender age_group             income     loc  \
# 13      3292596911   да   да      М     30-44    50.000 - 99.999  Горный
# 33      3292318652   да  нет      М     18-29    50.000 - 99.999  Горный
# 50      3292178389   да   да      М     18-29    50.000 - 99.999  Горный
# 54      3292162057   да   да      М     18-29  100.000 - 149.999  Горный
# 165     3291119656   да  нет      М     30-44    25.000 - 49.999  Горный
# 169     3291077381   да  нет      М     45-60           150.000+  Горный
# 206     3290987996   да   да      М     30-44         0 - 24.999  Горный
# 211     3290975724   да   да      М      > 60    50.000 - 99.999  Горный
# 247     3290906022   да  нет      М     45-60  100.000 - 149.999  Горный
# 269     3290860908   да   да      М     45-60         0 - 24.999  Горный
# 283     3290845752   да   да      М     30-44    50.000 - 99.999  Горный
# 304     3290804008   да   да      М     45-60                NaN  Горный
# ...

# %%
star[(star['fan']=='да')]['age_group'].value_counts()
# Out:
# 45-60    154
# 30-44    150
# 18-29    124
# > 60     113
# Name: age_group, dtype: int64

# %%
star[(star['fan']=='да') & (star['loc'] == 'Новая Англия') & (star['income'] == '0 - 24.999')]
# Out:
#       respondentID seen fan gender age_group      income           loc  \
# 58      3292144665   да  да      М     18-29  0 - 24.999  Новая Англия
# 442     3290565768   да  да      М     18-29  0 - 24.999  Новая Англия
# 476     3290471553   да  да      М     45-60  0 - 24.999  Новая Англия
# 477     3290467062   да  да      М     30-44  0 - 24.999  Новая Англия
# 564     3290216970   да  да      Ж     18-29  0 - 24.999  Новая Англия
# 656     3289996800   да  да      Ж     18-29  0 - 24.999  Новая Англия
# 918     3289354975   да  да      Ж     18-29  0 - 24.999  Новая Англия
# 970     3288722710   да  да      Ж     45-60  0 - 24.999  Новая Англия
# 1001    3288671328   да  да      Ж     18-29  0 - 24.999  Новая Англия
#
#                 yoda princess_leia_organa
# 58    очень нравится       очень нравится
# 442   очень нравится       очень нравится
# 476   очень нравится       очень нравится
# 477   очень нравится             нравится
# 564   очень нравится       очень нравится
# ...

# %%
star.shape
# Out:
# (1186, 9)

# %%
a = 9/1186*100
int(a)
# Out:
# 0

# %%
star['income'].isna().sum()
# Out:
# 328

# %%
star[(star['yoda'] == 'очень нравится') & (star['princess_leia_organa']== 'очень нравится')].shape
# Out:
# (462, 9)

# %%
star
# Out:
#       respondentID seen  fan gender age_group             income  \
# 0       3292879998   да   да      М     18-29                NaN
# 1       3292879538  нет  NaN      М     18-29         0 - 24.999
# 2       3292765271   да  нет      М     18-29         0 - 24.999
# 3       3292763116   да   да      М     18-29  100.000 - 149.999
# 4       3292731220   да   да      М     18-29  100.000 - 149.999
# ...            ...  ...  ...    ...       ...                ...
# 1181    3288388730   да   да      Ж     18-29         0 - 24.999
# 1182    3288378779   да   да      Ж     30-44    50.000 - 99.999
# 1183    3288375286  нет  NaN      Ж     30-44    50.000 - 99.999
# 1184    3288373068   да   да      Ж     45-60  100.000 - 149.999
# 1185    3288372923   да  нет      Ж      > 60    50.000 - 99.999
#
#                                loc                      yoda  \
# 0               Южно-Атлантический            очень нравится
# ...

# %%
star[(star['seen'] == 'нет') & (star['fan']== 'да')].shape
# Out:
# (0, 9)

# %%
star[(star['income'].isna()) & (star['fan'].isna()) & (star['gender'].isna()) 
     & (star['age_group'].isna())
    & (star['loc'].isna())
    & (star['yoda'].isna())
    & (star['princess_leia_organa'].isna())
    & (star['seen'].isna())].shape
#seen	fan	gender	age_group	income	loc	yoda	princess_leia_organa
# Out:
# respondentID            0.0
# seen                    0.0
# fan                     0.0
# gender                  0.0
# age_group               0.0
# income                  0.0
# loc                     0.0
# yoda                    0.0
# princess_leia_organa    0.0
# dtype: float64
